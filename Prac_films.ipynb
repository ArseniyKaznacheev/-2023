# %% [markdown]
# <a href="https://colab.research.google.com/github/ArseniyKaznacheev/-2023/blob/main/Prac_films.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import scipy
from scipy import stats
warnings.simplefilter("ignore")
import seaborn as sns
# %matplotlib inline
warnings.filterwarnings("ignore") # не вывожу предупреждающие сообщения

# %%
# %load_ext rpy2.ipython

# %%
# R
# %%R
# Выключаю вывод предупреждающих сообщений warning
oldw <- getOption("warn")
options(warn = -1)

install.packages("dplyr")
install.packages("Hmisc")
install.packages("ggplot2")
install.packages("highcharter")
install.packages("Leaflet")
install.packages("RColorBrewer")
install.packages("Plotly")
install.packages("sunburstR")
install.packages("RGL")
install.packages("dygraphs")
install.packages("outliers")
library(outliers)
install.packages("mice")
library(mice)
install.packages("corrplot")
library(corrplot)
install.packages('car')
library(car)

packages <- c('ggplot2', 'dplyr', 'tidyr', 'tibble')
library(tidyr)
library(tibble)

install.packages("nortest")
library(nortest)
install.packages("ggpubr")
set.seed(31600) # устанавливаю значение рандома по умолчанию

filter_data = function(data_frame, column, value){
  dplyr::filter(data_frame, !!as.symbol(column) == value)
}

# %%
# Python
films = pd.read_csv("film.csv", sep = ";",  encoding='latin-1')
films
# Out:
#       Year  Length                     Title Subject                Actor  \
# 0     1990   111.0   Tie Me Up! Tie Me Down!  Comedy    Banderas, Antonio
# 1     1991   113.0                High Heels  Comedy         Bosé, Miguel
# 2     1983   104.0            Dead Zone, The  Horror  Walken, Christopher
# 3     1979   122.0                      Cuba  Action        Connery, Sean
# 4     1978    94.0            Days of Heaven   Drama        Gere, Richard
# ...    ...     ...                       ...     ...                  ...
# 1654  1932   226.0  Shadow of the Eagle, The  Action          Wayne, John
# 1655  1989   103.0              Blood & Guns  Action        Welles, Orson
# 1656  1988    78.0                 Hot Money   Drama        Welles, Orson
# 1657  1977    75.0            Comedy Tonight  Comedy      Williams, Robin
# 1658  1991    65.0            Robin Williams  Comedy      Williams, Robin
#
#               Actress           Director  Popularity Awards            *Image
# ...

# %%
# R
#Читаем таблицы и удаляем пустые значения
# %%R
films <- read.csv(file = "film.csv")
films <- na.omit(films)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in read.table(file = file, header = header, sep = sep, quote = quote,  :
#   more columns than column names
# Error in read.table(file = file, header = header, sep = sep, quote = quote,  :
#   more columns than column names

# %%
import matplotlib
import matplotlib.pyplot as plt
sns.displot(x = 'Length', data = films, color = 'red', aspect = 2, height = 4, kde=True)

# %%
sns.displot(x = 'Length', data = films, color = 'red', aspect = 3, height = 4, hue = "Subject")

# %%
sns.displot(x = 'Length', data = films, color = 'red',aspect = 3, height = 4, kde = True, col = "Subject")

# %%
sns.displot(x = "Length",
            hue = "Subject",
            kind = "kde",
            fill = True,
            data = films);
